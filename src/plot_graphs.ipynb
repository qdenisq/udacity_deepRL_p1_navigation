# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-darkgrid')

# %% [markdown]
# ## Plot Scores

# %%
ddqn_fname=r'C:\Study\p1_navigation\reports\simple\ddqn_agent__10_18_2018_04_55_PM.npy'
dqn_fname=r'C:\Study\p1_navigation\reports\simple\dqn_agent__10_18_2018_05_09_PM.npy'
dqn_per_fname=r'C:\Study\p1_navigation\reports\visual\dqn_agent__10_23_2018_04_54_AM.npy'
# ddqn_per_fname=r'C:\Study\p1_navigation\reports\simple\ddqn_agent_PER_10_18_2018_04_40_PM.npy'
ddqn_per_fname=r'C:\Study\p1_navigation\reports\visual\dqn_agent__10_22_2018_03_44_AM.npy'

data = {}

data['dqn'] = np.load(dqn_fname)
data['ddqn'] = np.load(ddqn_fname)
data['dqn_per'] = np.load(dqn_per_fname)
data['ddqn_per'] = np.load(ddqn_per_fname)

palette = plt.get_cmap('Dark2')

plt.figure(figsize=(16,9))
plt.xlabel('Episodes', fontsize=18)
plt.ylabel('Score', fontsize=18)
for i, column in enumerate(['ddqn', 'dqn', 'dqn_per', 'ddqn_per']):
    smoothed = savgol_filter(data[column], 101, 1)
    average = np.convolve(data[column], np.ones(100)/100)
    plt.plot(average[:-100], label=column, linewidth=2, color=palette(i))
    plt.plot(data[column], linewidth=1, color=palette(i), alpha=0.2)
    plt.legend(fontsize=18)
    
plt.plot([13.0]*1000, linestyle='--', color=palette(10))
plt.show()
# Out:
# C:\ProgramData\Anaconda3\envs\drlnd\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]

# %% [markdown]
# ## Plot Losses

# %%
ddqn_fname=r'C:\Study\p1_navigation\reports\simple\ddqn_agent__loss_10_18_2018_04_55_PM.npy'
dqn_fname=r'C:\Study\p1_navigation\reports\simple\dqn_agent__loss_10_18_2018_05_09_PM.npy'
dqn_per_fname=r'C:\Study\p1_navigation\reports\visual\dqn_agent__loss_10_23_2018_04_54_AM.npy'
ddqn_per_fname=r'C:\Study\p1_navigation\reports\visual\dqn_agent__loss_10_22_2018_03_44_AM.npy'

data = {}

data['dqn'] = np.load(dqn_fname)
data['ddqn'] = np.load(ddqn_fname)
data['dqn_per'] = np.load(dqn_per_fname)
data['ddqn_per'] = np.load(ddqn_per_fname)

palette = plt.get_cmap('Dark2')

plt.figure(figsize=(16,9))
plt.xlabel('Episodes', fontsize=18)
plt.ylabel('Loss', fontsize=18)

for i, column in enumerate(['ddqn', 'dqn', 'dqn_per', 'ddqn_per']):
    smoothed = savgol_filter(data[column], 101, 1)
    average = np.convolve(data[column], np.ones(100)/100)
    plt.plot(average[:-100], label=column, linewidth=2, color=palette(i))
    plt.plot(data[column], linewidth=1, color=palette(i), alpha=0.2)
    plt.legend(fontsize=18)
    
plt.show()
# Out:
# C:\ProgramData\Anaconda3\envs\drlnd\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
